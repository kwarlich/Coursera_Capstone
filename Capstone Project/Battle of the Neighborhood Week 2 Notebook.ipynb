# %% [markdown]
# # Battle of the Neighborhoods

# %% [markdown]
# ## Table of Contents
# * [Introduction](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Results](#results)
# * [Discussion](#discussion)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a id="introduction"></a>

# %% [markdown]
# A client wants to open a comic book store. However, they are torn between selecting two different cities (El Segundo, California and Hermosa Beach, California). Another factor in consideration is that the business would be a speciality store and must exist with some distance from its competiton. The question is, "What would be the best city for the client's store with consideration for their competiton."

# %% [markdown]
# ## Data <a id='data'></a>

# %% [markdown]
# The data that will be used in this notebook will be.
#   * Load all the necesary libraies to manipulate data
#   * the creation of folium maps for each of the cities based on the locaiton data
#   * the Foursquare venue infomartion that  will be super-imposed on the maps
#   * general city infomation for each city from wikipedia
#     * "https://en.wikipedia.org/wiki/List_of_municipalities_in_California"

# %% [markdown]
# ### Libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

from geopy.geocoders import Nominatim #getting the location coordinates

from bs4 import BeautifulSoup # loading the tables from wikipedia

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#creating the map of the El Segundo
address = 'El Segundo, California'

geolocator = Nominatim(user_agent="CA_explorer")
location = geolocator.geocode(address)
ES_lat = location.latitude
ES_lng = location.longitude
print('The geograpical coordinates of El Segundo are {}, {}.'.format(ES_lat, ES_lng))
# Out:
# The geograpical coordinates of El Segundo are 33.917028, -118.4156337.

# %%
#creating the map of the Hermosa Beach
address = 'Hermosa Beach, California'

geolocator = Nominatim(user_agent="CA_explorer")
location = geolocator.geocode(address)
HB_lat = location.latitude
HB_lng = location.longitude
print('The geograpical coordinates of Hermosa Beach are {}, {}.'.format(HB_lat, HB_lng))
# Out:
# The geograpical coordinates of Hermosa Beach are 33.86428, -118.39591.

# %% [markdown]
# ### Using the Foursquare credentials to collect the venue information

# %%
CLIENT_ID = 'TAIL0VYFMOI2HD41UOZXJRO05VTNQZCPNAIKPL4EQGZ4DRI2' # your Foursquare ID
CLIENT_SECRET = 'DK0RICVRLNEYYVMQXKEGQGDAESI1ZD5KUFSMSZZEFJFVV3YY' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TAIL0VYFMOI2HD41UOZXJRO05VTNQZCPNAIKPL4EQGZ4DRI2
# CLIENT_SECRET:DK0RICVRLNEYYVMQXKEGQGDAESI1ZD5KUFSMSZZEFJFVV3YY

# %%
req = requests.get("https://en.wikipedia.org/wiki/List_of_municipalities_in_California") 
soup = BeautifulSoup(req.content,'lxml') 
table = soup.find_all('table')[1]  
df_data= pd.read_html(str(table)) 
df=pd.DataFrame(df_data[0])
df.head()
# Out:
#            Name  Type          County Population (2010)[1][8][9] Land area[1]  \
#            Name  Type          County Population (2010)[1][8][9]        sq mi
# 0      Adelanto  City  San Bernardino                      31765        56.01
# 1  Agoura Hills  City     Los Angeles                      20330         7.79
# 2       Alameda  City         Alameda                      73812        10.61
# 3        Albany  City         Alameda                      18539         1.79
# 4      Alhambra  City     Los Angeles                      83089         7.63
#
#              Incorporated[7]
#      km2     Incorporated[7]
# 0  145.1   December 22, 1970
# 1   20.2    December 8, 1982
# 2   27.5      April 19, 1854
# 3    4.6  September 22, 1908
# 4   19.8       July 11, 1903

# %% [markdown]
# ## Methodology <a id='methodolgu'></a>

# %% [markdown]
# In order to address the client's problem I will first want to create a map of the two cities using the folium libraries. Once the maps are complete, I would then use the foursquare location data for the location of the venues inside of each city. I would compile that information into two Pandas dataframes. Each of the dataframe would allow me to manipulate the information so I would be able to narrow down the type of venues that are not necessarily important to answer the question. When I would be able to see if there is another comic book store within the given areas. Once I able to swift through the information and the categories of venues, I could make recommendations to answer his problem.

# %% [markdown]
# ## Maps
#
# I will be creating the maps for the target cities to get a better sense of their location and layout.

# %%
#Creating a map of El Segundo from the latitude and longitude 

ES_map= folium.Map(location=[33.917028, -118.4156337], zoom_start=13)
ES_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3fab2db22ec744c9a90328d2d7761170%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3fab2db22ec744c9a90328d2d7761170%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3fab2db22ec744c9a90328d2d7761170%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3fab2db22ec744c9a90328d2d7761170%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B33.917028%2C%20-118.4156337%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# creating a folium map of Hermosa Beach based on latitude and longitude data

HB_map=folium.Map(location=[33.86428, -118.39591], zoom_start=13)
HB_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_aac449797373455191f3d8cd6243612d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_aac449797373455191f3d8cd6243612d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_aac449797373455191f3d8cd6243612d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_aac449797373455191f3d8cd6243612d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B33.86428%2C%20-118.39591%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# Since the maps of the target cities have been visualized, it will be easier to see and understand the types of venues and where they are placed within each of the cities. As well the a look at what surrounds the cities.

# %%
# This cell of code will get all the inofrmation of venues inside of El Segundo
LIMIT=100
radius=500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    ES_lat, 
    ES_lng, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=TAIL0VYFMOI2HD41UOZXJRO05VTNQZCPNAIKPL4EQGZ4DRI2&client_secret=DK0RICVRLNEYYVMQXKEGQGDAESI1ZD5KUFSMSZZEFJFVV3YY&v=20180605&ll=33.917028,-118.4156337&radius=500&limit=100'

# %%
# finding the reult of the venues
ES_results = requests.get(url).json()
ES_results
# Out:
# {'meta': {'code': 200, 'requestId': '6039c8124e785233ee5e8f77'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'},
#     {'name': '$-$$$$', 'key': 'price'}]},
#   'headerLocation': 'El Segundo',
#   'headerFullLocation': 'El Segundo',
#   'headerLocationGranularity': 'city',
#   'totalResults': 56,
#   'suggestedBounds': {'ne': {'lat': 33.921528004500004,
#     'lng': -118.41022112968353},
#    'sw': {'lat': 33.9125279955, 'lng': -118.42104627031647}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e30d618d22d33105980a212',
#        'name': 'El Segundo Brewing Company',
#        'location': {'address': '140 Main St',
#         'lat': 33.917753039416205,
#         'lng': -118.41559258096558,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.917753039416205,
#           'lng': -118.41559258096558},
#          {'label': 'entrance', 'lat': 33.91767, 'lng': -118.415813}],
#         'distance': 80,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['140 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e30d618d22d33105980a212-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58ae084a8927fd7e622755fe',
#        'name': 'Brewport Tap House',
#        'location': {'address': '204 Main St',
#         'crossStreet': 'Grand Avenue',
#         'lat': 33.918092812248126,
#         'lng': -118.41575906939856,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.918092812248126,
#           'lng': -118.41575906939856}],
#         'distance': 119,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['204 Main St (Grand Avenue)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d155941735',
#          'name': 'Gastropub',
#          'pluralName': 'Gastropubs',
#          'shortName': 'Gastropub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58ae084a8927fd7e622755fe-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b2c00a0911fc4002cc45057',
#        'name': 'Jame Enoteca',
#        'location': {'address': '241 Main St',
#         'crossStreet': 'Grand Ave',
#         'lat': 33.9183292054818,
#         'lng': -118.41610510594552,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.9183292054818,
#           'lng': -118.41610510594552}],
#         'distance': 151,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['241 Main St (Grand Ave)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2032165',
#         'url': 'https://www.grubhub.com/restaurant/jame-enoteca-241-main-st-el-segundo/2032165?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2032165',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b2c00a0911fc4002cc45057-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55ea653b498e795a59005349',
#        'name': 'Sausal',
#        'location': {'address': '219 Main St',
#         'lat': 33.918084513138886,
#         'lng': -118.4160482809006,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.918084513138886,
#           'lng': -118.4160482809006}],
#         'distance': 123,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['219 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2462259',
#         'url': 'https://www.grubhub.com/restaurant/sausal-219-main-st-el-segundo/2462259?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2462259',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55ea653b498e795a59005349-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7e2876f964a52039f11fe3',
#        'name': 'El Tarasco Mexican Food',
#        'location': {'address': '210 Main St',
#         'crossStreet': 'btw Grand & Franklin',
#         'lat': 33.91828622576286,
#         'lng': -118.4158448531121,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91828622576286,
#           'lng': -118.4158448531121},
#          {'label': 'entrance', 'lat': 33.918306, 'lng': -118.415817}],
#         'distance': 141,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['210 Main St (btw Grand & Franklin)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1429278',
#         'url': 'https://www.grubhub.com/restaurant/el-tarasco-mexican-food-210-main-st-el-segundo/1429278?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1429278',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7e2876f964a52039f11fe3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '49d02759f964a520045b1fe3',
#        'name': 'Good Stuff Restaurant',
#        'location': {'address': '131 W Grand Ave Ste C',
#         'lat': 33.91918575953068,
#         'lng': -118.41707477563375,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91918575953068,
#           'lng': -118.41707477563375}],
#         'distance': 274,
#         'postalCode': '90245',
#         'cc': 'US',
#         'neighborhood': 'Downtown El Segundo',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['131 W Grand Ave Ste C',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-49d02759f964a520045b1fe3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac84dbef964a52015bc20e3',
#        'name': 'Havana Sandwich Company',
#        'location': {'address': '229 Main St',
#         'crossStreet': 'Grand Avenue',
#         'lat': 33.91826366803479,
#         'lng': -118.41610922747468,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91826366803479,
#           'lng': -118.41610922747468}],
#         'distance': 144,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['229 Main St (Grand Avenue)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d154941735',
#          'name': 'Cuban Restaurant',
#          'pluralName': 'Cuban Restaurants',
#          'shortName': 'Cuban',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cuban_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '317687',
#         'url': 'https://www.grubhub.com/restaurant/havana-sandwich-company-229-main-st-el-segundo/317687?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=317687',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ac84dbef964a52015bc20e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb2068df964a520e4b23ce3',
#        'name': 'imFORZA',
#        'location': {'address': '319 Main St',
#         'crossStreet': 'Grand Avenue',
#         'lat': 33.919663743051075,
#         'lng': -118.41614460945112,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.919663743051075,
#           'lng': -118.41614460945112}],
#         'distance': 297,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['319 Main St (Grand Avenue)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b36',
#          'name': 'IT Services',
#          'pluralName': 'IT Services',
#          'shortName': 'IT Services',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb2068df964a520e4b23ce3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a2a08a2be7078595d169a36',
#        'name': 'Ensenada’s Surf N Turf Grill',
#        'location': {'address': '310 E Grand Ave',
#         'crossStreet': 'Eucalyptus Dr.',
#         'lat': 33.9191807182305,
#         'lng': -118.41334013062055,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.9191807182305,
#           'lng': -118.41334013062055}],
#         'distance': 319,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['310 E Grand Ave (Eucalyptus Dr.)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d151941735',
#          'name': 'Taco Place',
#          'pluralName': 'Taco Places',
#          'shortName': 'Tacos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/taco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2339557',
#         'url': 'https://www.grubhub.com/restaurant/ensenadas-surf-n-turf-grill-310-e-grand-ave-ste-112-el-segundo/2339557?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2339557',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a2a08a2be7078595d169a36-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ddf3dfb7d8b04e50258e981',
#        'name': 'Standard Station',
#        'location': {'address': '226 Standard St',
#         'lat': 33.91861785298578,
#         'lng': -118.41470779274701,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91861785298578,
#           'lng': -118.41470779274701}],
#         'distance': 196,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['226 Standard St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ddf3dfb7d8b04e50258e981-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5de5da7735c9b6ab839072',
#        'name': 'Rock & Brews',
#        'location': {'address': '143 Main St',
#         'lat': 33.9175058,
#         'lng': -118.4161505,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.9175058,
#           'lng': -118.4161505}],
#         'distance': 71,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['143 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '128595258'}},
#       'referralId': 'e-0-4c5de5da7735c9b6ab839072-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5900ab34a879210ea737743f',
#        'name': 'Two Guns Kitchen',
#        'location': {'address': '321 Main St',
#         'crossStreet': 'Grand Ave',
#         'lat': 33.91982733829685,
#         'lng': -118.41611664168721,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91982733829685,
#           'lng': -118.41611664168721}],
#         'distance': 314,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['321 Main St (Grand Ave)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5900ab34a879210ea737743f-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b609c79f964a52024f029e3',
#        'name': 'Deluca Trattoria',
#        'location': {'address': '225 Richmond St',
#         'crossStreet': 'Grand Avenue',
#         'lat': 33.91865025090203,
#         'lng': -118.41731195973301,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91865025090203,
#           'lng': -118.41731195973301},
#          {'label': 'entrance', 'lat': 33.918661, 'lng': -118.417255}],
#         'distance': 238,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['225 Richmond St (Grand Avenue)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '343896106'}},
#       'referralId': 'e-0-4b609c79f964a52024f029e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c4bb64fa5a31500390f69ac',
#        'name': 'The Slice And Pint',
#        'location': {'address': '130 W Grand Ave',
#         'crossStreet': 'Richmond St',
#         'lat': 33.91892284042895,
#         'lng': -118.41692796647827,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91892284042895,
#           'lng': -118.41692796647827}],
#         'distance': 242,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['130 W Grand Ave (Richmond St)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c4bb64fa5a31500390f69ac-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af48396f964a52061f321e3',
#        'name': 'Starbucks',
#        'location': {'address': '310 E Grand Ave',
#         'lat': 33.91911070271755,
#         'lng': -118.41339936401269,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91911070271755,
#           'lng': -118.41339936401269}],
#         'distance': 310,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['310 E Grand Ave',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af48396f964a52061f321e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a99f386f964a520383120e3',
#        'name': 'Blimpie',
#        'location': {'address': '130 East Grand Ave, Suite E',
#         'crossStreet': 'at Standard St',
#         'lat': 33.91845850668509,
#         'lng': -118.4151556997476,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91845850668509,
#           'lng': -118.4151556997476},
#          {'label': 'entrance', 'lat': 33.918937, 'lng': -118.415179}],
#         'distance': 165,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['130 East Grand Ave, Suite E (at Standard St)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '705006',
#         'url': 'https://www.grubhub.com/restaurant/blimpie-130-e-grand-ave-ste-e-el-segundo/705006?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=705006',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a99f386f964a520383120e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af507d4f964a52012f821e3',
#        'name': 'Second City Bistro',
#        'location': {'address': '223 Richmond St',
#         'crossStreet': 'Grand Ave & Richmond St',
#         'lat': 33.91862038735844,
#         'lng': -118.41731786482656,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91862038735844,
#           'lng': -118.41731786482656},
#          {'label': 'entrance', 'lat': 33.918592, 'lng': -118.417255}],
#         'distance': 235,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['223 Richmond St (Grand Ave & Richmond St)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '134258138'}},
#       'referralId': 'e-0-4af507d4f964a52012f821e3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c585a586201e21e94a05a70',
#        'name': 'The Studio Art of Dance',
#        'location': {'address': '113 Main St',
#         'lat': 33.91684771648374,
#         'lng': -118.41565706295317,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91684771648374,
#           'lng': -118.41565706295317}],
#         'distance': 20,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['113 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d134941735',
#          'name': 'Dance Studio',
#          'pluralName': 'Dance Studios',
#          'shortName': 'Dance Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c585a586201e21e94a05a70-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a8f0135f964a5208b1320e3',
#        'name': 'Blue Butterfly',
#        'location': {'address': '351 Main St',
#         'lat': 33.920577080470956,
#         'lng': -118.4161227239033,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.920577080470956,
#           'lng': -118.4161227239033},
#          {'label': 'entrance', 'lat': 33.920488, 'lng': -118.416075}],
#         'distance': 397,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['351 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1134167',
#         'url': 'https://www.grubhub.com/restaurant/blue-butterfly-coffee-company-351-main-st-el-segundo/1134167?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1134167',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a8f0135f964a5208b1320e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57991076498e90e7f480a925',
#        'name': 'Cold Stone Creamery',
#        'location': {'address': '130 E Grand Ave, Ste E',
#         'lat': 33.918439,
#         'lng': -118.415126,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.918439,
#           'lng': -118.415126}],
#         'distance': 163,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['130 E Grand Ave, Ste E',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '695510',
#         'url': 'https://www.grubhub.com/restaurant/cold-stone-creamery-130-e-grand-ave-ste-e-el-segundo/695510?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=695510',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57991076498e90e7f480a925-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a7676faf964a5200de31fe3',
#        'name': 'The Tavern on Main',
#        'location': {'address': '123 Main St',
#         'crossStreet': 'off El Segundo Blvd.',
#         'lat': 33.917316432380325,
#         'lng': -118.41607403065326,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.917316432380325,
#           'lng': -118.41607403065326},
#          {'label': 'entrance', 'lat': 33.917348, 'lng': -118.416074}],
#         'distance': 51,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['123 Main St (off El Segundo Blvd.)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a7676faf964a5200de31fe3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af5d16ef964a52041fd21e3',
#        'name': 'Chicken Dijon',
#        'location': {'address': '251 Main St',
#         'crossStreet': 'at W Grand Ave',
#         'lat': 33.9184992,
#         'lng': -118.416418,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.9184992,
#           'lng': -118.416418}],
#         'distance': 179,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['251 Main St (at W Grand Ave)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c0941735',
#          'name': 'Mediterranean Restaurant',
#          'pluralName': 'Mediterranean Restaurants',
#          'shortName': 'Mediterranean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '73373',
#         'url': 'https://www.grubhub.com/restaurant/chicken-dijon-el-segundo-251-main-st-el-segundo/73373?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=73373',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af5d16ef964a52041fd21e3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a9463a0f964a5206a2120e3',
#        'name': "The Original Rinaldi's",
#        'location': {'address': '323 Main St',
#         'crossStreet': 'btw Grand & Holly',
#         'lat': 33.91986,
#         'lng': -118.4161488,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91986,
#           'lng': -118.4161488}],
#         'distance': 318,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['323 Main St (btw Grand & Holly)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '551833',
#         'url': 'https://www.grubhub.com/restaurant/the-original-rinaldis---es-323-main-st-el-segundo/551833?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=551833',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a9463a0f964a5206a2120e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5246323d498e741aa8799323',
#        'name': '99 Cents Only Stores',
#        'location': {'address': '300 Richmond St,',
#         'crossStreet': 'Grand',
#         'lat': 33.919789,
#         'lng': -118.416963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.919789,
#           'lng': -118.416963},
#          {'label': 'entrance', 'lat': 33.919981, 'lng': -118.417074}],
#         'distance': 330,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['300 Richmond St, (Grand)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'shortName': 'Discount Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5246323d498e741aa8799323-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53a0949a498e1b07527c7bc1',
#        'name': 'Petros Kafe',
#        'location': {'lat': 33.91916503028582,
#         'lng': -118.41667920992704,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91916503028582,
#           'lng': -118.41667920992704}],
#         'distance': 256,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['El Segundo, CA 90245', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'shortName': 'Greek',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53a0949a498e1b07527c7bc1-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbe37608ca376b0127fc77a',
#        'name': "Britt's BBQ",
#        'location': {'address': '408 Main St',
#         'crossStreet': 'Holly Ave.',
#         'lat': 33.92126109052454,
#         'lng': -118.41574685092621,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.92126109052454,
#           'lng': -118.41574685092621}],
#         'distance': 471,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['408 Main St (Holly Ave.)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '206371',
#         'url': 'https://www.grubhub.com/restaurant/britts-bbq-408-main-st-el-segundo/206371?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=206371',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbe37608ca376b0127fc77a-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '455e14c5f964a520833d1fe3',
#        'name': 'Purple Orchid',
#        'location': {'address': '221 Richmond St',
#         'crossStreet': 'btwn Grand & Franklin',
#         'lat': 33.91864729630572,
#         'lng': -118.41730136484249,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91864729630572,
#           'lng': -118.41730136484249},
#          {'label': 'entrance', 'lat': 33.918523, 'lng': -118.417256}],
#         'distance': 237,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['221 Richmond St (btwn Grand & Franklin)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-455e14c5f964a520833d1fe3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8b48faf964a520dd9a32e3',
#        'name': 'Old Town Music Hall',
#        'location': {'address': '140 Richmond St',
#         'lat': 33.91759774553986,
#         'lng': -118.41701712850438,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91759774553986,
#           'lng': -118.41701712850438},
#          {'label': 'entrance', 'lat': 33.917624, 'lng': -118.417056}],
#         'distance': 142,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['140 Richmond St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d17f941735',
#          'name': 'Movie Theater',
#          'pluralName': 'Movie Theaters',
#          'shortName': 'Movie Theater',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8b48faf964a520dd9a32e3-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d013f47432f548158abc154',
#        'name': 'Stix & Straws',
#        'location': {'address': '310 E Grand Ave',
#         'lat': 33.91916222241096,
#         'lng': -118.4130652929525,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91916222241096,
#           'lng': -118.4130652929525}],
#         'distance': 335,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['310 E Grand Ave',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '499354',
#         'url': 'https://www.grubhub.com/restaurant/stix--straws-310-e-grand-ave-el-segundo/499354?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=499354',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d013f47432f548158abc154-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4a8da3f964a520798a26e3',
#        'name': 'Hana Haru',
#        'location': {'address': '409 Main St',
#         'lat': 33.92114497466819,
#         'lng': -118.41612770293712,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.92114497466819,
#           'lng': -118.41612770293712},
#          {'label': 'entrance', 'lat': 33.921162, 'lng': -118.416059}],
#         'distance': 460,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['409 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '549736',
#         'url': 'https://www.grubhub.com/restaurant/hana-haru-sushi-409-main-st-el-segundo/549736?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=549736',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4a8da3f964a520798a26e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b40dbf4f964a5205bbc25e3',
#        'name': 'Fantastic Cafe',
#        'location': {'address': '412 Main St.',
#         'lat': 33.92132880390449,
#         'lng': -118.41581854316298,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.92132880390449,
#           'lng': -118.41581854316298}],
#         'distance': 479,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['412 Main St.',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b40dbf4f964a5205bbc25e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '565d0c3e38fabeb3317e44e9',
#        'name': 'Kagura',
#        'location': {'address': '403 Main Street',
#         'crossStreet': 'Holly',
#         'lat': 33.9210412715171,
#         'lng': -118.416095659041,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.9210412715171,
#           'lng': -118.416095659041}],
#         'distance': 448,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['403 Main Street (Holly)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-565d0c3e38fabeb3317e44e9-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af50499f964a52001f821e3',
#        'name': "Wendy's Place",
#        'location': {'address': '107 W Grand Ave',
#         'crossStreet': 'btw Main & Richmond',
#         'lat': 33.919140607073274,
#         'lng': -118.41632978107329,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.919140607073274,
#           'lng': -118.41632978107329}],
#         'distance': 243,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['107 W Grand Ave (btw Main & Richmond)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'shortName': 'Diner',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af50499f964a52001f821e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a9440e2f964a520ee2020e3',
#        'name': 'Siam Bay',
#        'location': {'address': '130 Grand Ave., Suite D',
#         'crossStreet': 'Grand and Standard',
#         'lat': 33.91852137688775,
#         'lng': -118.41512459451343,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91852137688775,
#           'lng': -118.41512459451343},
#          {'label': 'entrance', 'lat': 33.918937, 'lng': -118.415179}],
#         'distance': 172,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
# ...
#         'distance': 441,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['403 Main St (at E Holly Ave)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e0c03a0814de825c6de02f2-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d448506bf61a1cde8c309ac',
#        'name': "Vinny's Pizza",
#        'location': {'address': '310 E Grand Ave Ste 109',
#         'lat': 33.919169348665704,
#         'lng': -118.41309189718208,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.919169348665704,
#           'lng': -118.41309189718208}],
#         'distance': 334,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['310 E Grand Ave Ste 109',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1135287',
#         'url': 'https://www.grubhub.com/restaurant/vinnys-pizza-310-e-grand-ave-el-segundo/1135287?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1135287',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d448506bf61a1cde8c309ac-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a554e87f964a5200db41fe3',
#        'name': 'Richmond Bar & Grill',
#        'location': {'address': '145 Richmond St',
#         'crossStreet': 'Franklin Ave',
#         'lat': 33.91774756572532,
#         'lng': -118.41732235951908,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91774756572532,
#           'lng': -118.41732235951908}],
#         'distance': 175,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['145 Richmond St (Franklin Ave)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a554e87f964a5200db41fe3-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a592ed2f964a520e9b81fe3',
#        'name': 'Old Town Patio',
#        'location': {'address': '115 Richmond St',
#         'crossStreet': 'btw Franklin & El Segundo Blvd.',
#         'lat': 33.916938882342514,
#         'lng': -118.41746170318248,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.916938882342514,
#           'lng': -118.41746170318248},
#          {'label': 'entrance', 'lat': 33.917045, 'lng': -118.417251}],
#         'distance': 169,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['115 Richmond St (btw Franklin & El Segundo Blvd.)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a592ed2f964a520e9b81fe3-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a789119f964a520e6e51fe3',
#        'name': 'Playa Blanca',
#        'location': {'address': '413 Main St',
#         'lat': 33.92131691567325,
#         'lng': -118.41611331517458,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.92131691567325,
#           'lng': -118.41611331517458},
#          {'label': 'entrance', 'lat': 33.921243, 'lng': -118.416075}],
#         'distance': 479,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['413 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a789119f964a520e6e51fe3-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b677e5cf964a52032522be3',
#        'name': 'The UPS Store',
#        'location': {'address': '214 Main St',
#         'lat': 33.9183235,
#         'lng': -118.4156562,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.9183235,
#           'lng': -118.4156562}],
#         'distance': 144,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['214 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b1f',
#          'name': 'Shipping Store',
#          'pluralName': 'Shipping Stores',
#          'shortName': 'Shipping Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b677e5cf964a52032522be3-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56fc252a498ed135a5ba79d0',
#        'name': 'Pho Dreams',
#        'location': {'address': '413 Main St',
#         'lat': 33.92130643107371,
#         'lng': -118.41603758228482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.92130643107371,
#           'lng': -118.41603758228482}],
#         'distance': 477,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['413 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56fc252a498ed135a5ba79d0-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af50518f964a52006f821e3',
#        'name': 'Chef Hannes Restaurant',
#        'location': {'address': '411 Main St',
#         'crossStreet': 'btw Holly & Pine',
#         'lat': 33.92121542227015,
#         'lng': -118.4160644623193,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.92121542227015,
#           'lng': -118.4160644623193},
#          {'label': 'entrance', 'lat': 33.921219, 'lng': -118.416075}],
#         'distance': 467,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['411 Main St (btw Holly & Pine)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af50518f964a52006f821e3-50'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b634b2df964a5204a702ae3',
#        'name': 'Little Gourmet',
#        'location': {'address': '117 Main St',
#         'crossStreet': 'at E Franklin Ave',
#         'lat': 33.917189420232205,
#         'lng': -118.41607138764356,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.917189420232205,
#           'lng': -118.41607138764356},
#          {'label': 'entrance', 'lat': 33.917173, 'lng': -118.416058}],
#         'distance': 44,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['117 Main St (at E Franklin Ave)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b634b2df964a5204a702ae3-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5103594ce4b0b154c703b442',
#        'name': 'ESMoA',
#        'location': {'address': '208 Main St',
#         'lat': 33.918063000000004,
#         'lng': -118.41565600000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.918063000000004,
#           'lng': -118.41565600000001},
#          {'label': 'entrance', 'lat': 33.918097, 'lng': -118.415803}],
#         'distance': 115,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['208 Main St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d18f941735',
#          'name': 'Art Museum',
#          'pluralName': 'Art Museums',
#          'shortName': 'Art Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_art_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5103594ce4b0b154c703b442-52'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ad7cb86f964a520d10e21e3',
#        'name': 'Looks etc',
#        'location': {'address': '120 W Grand ave',
#         'lat': 33.918894,
#         'lng': -118.416704,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.918894,
#           'lng': -118.416704}],
#         'distance': 230,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['120 W Grand ave',
#          'Los Angeles, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ad7cb86f964a520d10e21e3-53'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af9d988f964a520c21422e3',
#        'name': 'Hanabi',
#        'location': {'address': '310 E Grand Ave',
#         'crossStreet': 'btw Main St & Sepulveda',
#         'lat': 33.91921861838832,
#         'lng': -118.41325806538833,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.91921861838832,
#           'lng': -118.41325806538833}],
#         'distance': 328,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['310 E Grand Ave (btw Main St & Sepulveda)',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4af9d988f964a520c21422e3-54'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c898dfce51e6dcb2e9061de',
#        'name': 'Studio Antiques',
#        'location': {'address': '337 Richmond St',
#         'lat': 33.919958,
#         'lng': -118.417368,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.919958,
#           'lng': -118.417368},
#          {'label': 'entrance', 'lat': 33.919958, 'lng': -118.41728}],
#         'distance': 363,
#         'postalCode': '90245',
#         'cc': 'US',
#         'city': 'El Segundo',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['337 Richmond St',
#          'El Segundo, CA 90245',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116951735',
#          'name': 'Antique Shop',
#          'pluralName': 'Antique Shops',
#          'shortName': 'Antiques',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '136570547'}},
#       'referralId': 'e-0-4c898dfce51e6dcb2e9061de-55'}]}]}}

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = ES_results['response']['groups'][0]['items']
    
ESnearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
ESnearby_venues =ESnearby_venues.loc[:, filtered_columns]

# filter the category for each row
ESnearby_venues['venue.categories'] = ESnearby_venues.apply(get_category_type, axis=1)

# clean columns
ESnearby_venues.columns = [col.split(".")[-1] for col in ESnearby_venues.columns]

ESnearby_venues.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                          name          categories        lat         lng
# 0  El Segundo Brewing Company             Brewery  33.917753 -118.415593
# 1          Brewport Tap House           Gastropub  33.918093 -118.415759
# 2                Jame Enoteca  Italian Restaurant  33.918329 -118.416105
# 3                      Sausal  Mexican Restaurant  33.918085 -118.416048
# 4     El Tarasco Mexican Food  Mexican Restaurant  33.918286 -118.415845

# %%
#looking for the unique categories of the venues
print('There are {} uniques categories.'.format(len(ESnearby_venues['categories'].unique())))
# Out:
# There are 42 uniques categories.

# %%
#Looking at the categories to see if any of the venues in El Segundo match the client's category forhgis business
ESnearby_venues["categories"]
# Out:
# 0                       Brewery
# 1                     Gastropub
# 2            Italian Restaurant
# 3            Mexican Restaurant
# 4            Mexican Restaurant
# 5           American Restaurant
# 6              Cuban Restaurant
# 7                   IT Services
# 8                    Taco Place
# 9                    Sports Bar
# 10          American Restaurant
# 11                  Coffee Shop
# 12           Italian Restaurant
# 13                  Pizza Place
# 14                  Coffee Shop
# 15         Fast Food Restaurant
# 16          American Restaurant
# 17                 Dance Studio
# 18                  Coffee Shop
# 19               Ice Cream Shop
# 20                          Bar
# 21     Mediterranean Restaurant
# 22               Sandwich Place
# 23               Discount Store
# 24             Greek Restaurant
# 25                    BBQ Joint
# 26                 Cocktail Bar
# 27                Movie Theater
# 28                   Restaurant
# 29          Japanese Restaurant
# 30                        Diner
# 31          Japanese Restaurant
# 32                        Diner
# 33              Thai Restaurant
# 34                  Pizza Place
# 35            Indian Restaurant
# 36               Farmers Market
# 37     Mediterranean Restaurant
# 38          Rental Car Location
# 39                     Pharmacy
# 40                         Bank
# 41                     Dive Bar
# 42          Japanese Restaurant
# 43                     Wine Bar
# 44                  Pizza Place
# 45                 Burger Joint
# 46                   Sports Bar
# 47    Latin American Restaurant
# 48               Shipping Store
# 49        Vietnamese Restaurant
# 50            French Restaurant
# 51               Sandwich Place
# 52                   Art Museum
# 53                          Spa
# 54             Sushi Restaurant
# 55                 Antique Shop
# Name: categories, dtype: object

# %%
ESV_map=folium.Map(location=[33.917028, -118.4156337], zoom_start=17)
for i,row in ESnearby_venues.iterrows():
    folium.Marker(location=[row['lat'],row['lng']], popup=row["name"]).add_to(ESV_map)
ESV_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_c458ada2107f44a6988f10b2f343c6f3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_c458ada2107f44a6988f10b2f343c6f3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_c458ada2107f44a6988f10b2f343c6f3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_c458ada2107f44a6988f10b2f343c6f3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B33.917028%2C%20-118.4156337%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %% [markdown]
# The results of the foursquare data super imposed on the folium map

# %%
# This cell of code will get all the inofrmation of venues inside of Hermosa Beach
LIMIT=100
radius=500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    HB_lat, 
    HB_lng, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=TAIL0VYFMOI2HD41UOZXJRO05VTNQZCPNAIKPL4EQGZ4DRI2&client_secret=DK0RICVRLNEYYVMQXKEGQGDAESI1ZD5KUFSMSZZEFJFVV3YY&v=20180605&ll=33.86428,-118.39591&radius=500&limit=100'

# %%
HB_results = requests.get(url).json()
HB_results
# Out:
# {'meta': {'code': 200, 'requestId': '6039c813a6f02c11e2e3c422'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Hermosa Beach',
#   'headerFullLocation': 'Hermosa Beach',
#   'headerLocationGranularity': 'city',
#   'totalResults': 70,
#   'suggestedBounds': {'ne': {'lat': 33.8687800045, 'lng': -118.39050077587581},
#    'sw': {'lat': 33.8597799955, 'lng': -118.4013192241242}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1ee637f964a520432124e3',
#        'name': 'Creme de la Crepe',
#        'location': {'address': '424 Pier Ave',
#         'lat': 33.8641795028075,
#         'lng': -118.39710441028895,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.8641795028075,
#           'lng': -118.39710441028895},
#          {'label': 'entrance', 'lat': 33.864129, 'lng': -118.39708}],
#         'distance': 110,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['424 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2374297',
#         'url': 'https://www.grubhub.com/restaurant/creme-de-la-crepe-424-pier-ave-hermosa-beach/2374297?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2374297',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1ee637f964a520432124e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52d06f3a11d2c571e39c8889',
#        'name': 'Hermosa Beach Fish Shop',
#        'location': {'address': '719 Pier Ave',
#         'lat': 33.86502832965717,
#         'lng': -118.394181607406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86502832965717,
#           'lng': -118.394181607406}],
#         'distance': 180,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['719 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '90989513'}},
#       'referralId': 'e-0-52d06f3a11d2c571e39c8889-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1b2056f964a52084f823e3',
#        'name': 'Fritto Misto Italian Cafe',
#        'location': {'address': '316 Pier Ave',
#         'lat': 33.86377411372527,
#         'lng': -118.39814914483836,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86377411372527,
#           'lng': -118.39814914483836},
#          {'label': 'entrance', 'lat': 33.86379, 'lng': -118.39808}],
#         'distance': 214,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['316 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1b2056f964a52084f823e3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50dca3a9e4b08766e1785d63',
#        'name': 'The Source Cafe',
#        'location': {'address': '509 Pier Ave',
#         'crossStreet': 'Bard St',
#         'lat': 33.86449883975705,
#         'lng': -118.39665127938063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86449883975705,
#           'lng': -118.39665127938063}],
#         'distance': 72,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['509 Pier Ave (Bard St)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50dca3a9e4b08766e1785d63-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b41091af964a520d4bf25e3',
#        'name': 'The Strand',
#        'location': {'address': 'Strand Ave',
#         'lat': 33.86703010948111,
#         'lng': -118.3949040419306,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86703010948111,
#           'lng': -118.3949040419306}],
#         'distance': 319,
#         'postalCode': '90266',
#         'cc': 'US',
#         'city': 'Manhattan & Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Strand Ave',
#          'Manhattan & Hermosa Beach, CA 90266',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b41091af964a520d4bf25e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7b88b8f964a5208a662fe3',
#        'name': 'Bikram Yoga',
#        'location': {'address': '518 Pier Ave',
#         'lat': 33.8641946502682,
#         'lng': -118.39640009384745,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.8641946502682,
#           'lng': -118.39640009384745}],
#         'distance': 46,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['518 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7b88b8f964a5208a662fe3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5e0ebf60ed0b1c00078acdc6',
#        'name': 'The Habit Burger Grill',
#        'location': {'address': '719 Pier Ave',
#         'lat': 33.86514663696289,
#         'lng': -118.3939437866211,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86514663696289,
#           'lng': -118.3939437866211}],
#         'distance': 205,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['719 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5e0ebf60ed0b1c00078acdc6-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ebdeed430f82a2e12477017',
#        'name': 'Uncorked The Wine Shop',
#        'location': {'address': '302 Pier Ave',
#         'crossStreet': 'Hermosa Ave.',
#         'lat': 33.86364855331688,
#         'lng': -118.39826188338424,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86364855331688,
#           'lng': -118.39826188338424}],
#         'distance': 228,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['302 Pier Ave (Hermosa Ave.)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d119951735',
#          'name': 'Wine Shop',
#          'pluralName': 'Wine Shops',
#          'shortName': 'Wine Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '46076374'}},
#       'referralId': 'e-0-4ebdeed430f82a2e12477017-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4adce276f964a520376221e3',
#        'name': 'Chipotle Mexican Grill',
#        'location': {'address': '1439 Pacific Coast Hwy',
#         'crossStreet': 'at Pier Ave',
#         'lat': 33.86533148472044,
#         'lng': -118.39348661381166,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86533148472044,
#           'lng': -118.39348661381166}],
#         'distance': 252,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1439 Pacific Coast Hwy (at Pier Ave)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4adce276f964a520376221e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9c0361f964a520c64036e3',
#        'name': 'The Gum Tree Cafe & Boutique',
#        'location': {'address': '238 Pier Ave',
#         'lat': 33.8632801688798,
#         'lng': -118.39868036260397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.8632801688798,
#           'lng': -118.39868036260397},
#          {'label': 'entrance', 'lat': 33.863167, 'lng': -118.398746}],
#         'distance': 279,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['238 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d169941735',
#          'name': 'Australian Restaurant',
#          'pluralName': 'Australian Restaurants',
#          'shortName': 'Australian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9c0361f964a520c64036e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd4582c091abf67d5ed3547',
#        'name': 'The Rockefeller',
#        'location': {'address': '418-422 Pier Ave',
#         'crossStreet': 'Cypress Street',
#         'lat': 33.86403721293303,
#         'lng': -118.39726827555609,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86403721293303,
#           'lng': -118.39726827555609},
#          {'label': 'entrance', 'lat': 33.864117, 'lng': -118.397144}],
#         'distance': 128,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['418-422 Pier Ave (Cypress Street)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd4582c091abf67d5ed3547-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b451bb7f964a520e40426e3',
#        'name': 'El Pollo Inka',
#        'location': {'address': '1100 Pacific Coast Hwy',
#         'crossStreet': 'at Aviation Blvd.',
#         'lat': 33.86349764622628,
#         'lng': -118.39199760352746,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86349764622628,
#           'lng': -118.39199760352746}],
#         'distance': 371,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1100 Pacific Coast Hwy (at Aviation Blvd.)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4eb1bfa43b7b52c0e1adc2e8',
#          'name': 'Peruvian Restaurant',
#          'pluralName': 'Peruvian Restaurants',
#          'shortName': 'Peruvian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/peruvian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '429826',
#         'url': 'https://www.grubhub.com/restaurant/el-pollo-inka-1100-pacific-coast-hwy-hermosa-beach/429826?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=429826',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b451bb7f964a520e40426e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bfee0c34e5d0f476d4c7d1f',
#        'name': 'Massage Spot',
#        'location': {'address': '507 Pier Ave #B',
#         'lat': 33.864534425607076,
#         'lng': -118.39669538680252,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.864534425607076,
#           'lng': -118.39669538680252}],
#         'distance': 77,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['507 Pier Ave #B',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#          'name': 'Massage Studio',
#          'pluralName': 'Massage Studios',
#          'shortName': 'Massage Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bfee0c34e5d0f476d4c7d1f-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52d833d5498e311adcc21277',
#        'name': 'Día de Campo',
#        'location': {'address': '1238 Hermosa Ave',
#         'crossStreet': 'between Pier and 14th',
#         'lat': 33.8628627726685,
#         'lng': -118.40000999326466,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.8628627726685,
#           'lng': -118.40000999326466},
#          {'label': 'entrance', 'lat': 33.862894, 'lng': -118.400019}],
#         'distance': 410,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1238 Hermosa Ave (between Pier and 14th)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '778195',
#         'url': 'https://www.grubhub.com/restaurant/dia-de-campo-1238-hermosa-ave-hermosa-beach/778195?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=778195',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '76358781'}},
#       'referralId': 'e-0-52d833d5498e311adcc21277-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6a742945ddadf2d07b18b8',
#        'name': 'Deep Pocket Jean Company',
#        'location': {'address': '200 Pier Ave Ste 201',
#         'lat': 33.86311498326492,
#         'lng': -118.3990078966402,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86311498326492,
#           'lng': -118.3990078966402}],
#         'distance': 314,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['200 Pier Ave Ste 201',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d106951735',
#          'name': "Men's Store",
#          'pluralName': "Men's Stores",
#          'shortName': "Men's Store",
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '48428531'}},
#       'referralId': 'e-0-4e6a742945ddadf2d07b18b8-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aee15fef964a520f2d121e3',
#        'name': 'Planet Earth Eco Cafe',
#        'location': {'address': '509 Pier Ave',
#         'crossStreet': 'at Bard St',
#         'lat': 33.86453654464121,
#         'lng': -118.39668169366543,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86453654464121,
#           'lng': -118.39668169366543},
#          {'label': 'entrance', 'lat': 33.864482, 'lng': -118.396657}],
#         'distance': 76,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['509 Pier Ave (at Bard St)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aee15fef964a520f2d121e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f185d0ce4b078805d3c7b53',
#        'name': 'Abigaile',
#        'location': {'address': '1301 Manhattan Ave',
#         'crossStreet': 'Pier Avenue',
#         'lat': 33.86315921211213,
#         'lng': -118.3996006892727,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86315921211213,
#           'lng': -118.3996006892727}],
#         'distance': 363,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1301 Manhattan Ave (Pier Avenue)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'shortName': 'New American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f185d0ce4b078805d3c7b53-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53815fe3498e54e075cb2652',
#        'name': 'The Standing Room',
#        'location': {'address': '1320 Hermosa Ave',
#         'lat': 33.86326862237598,
#         'lng': -118.40013741345278,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86326862237598,
#           'lng': -118.40013741345278}],
#         'distance': 406,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1320 Hermosa Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '94374906'}},
#       'referralId': 'e-0-53815fe3498e54e075cb2652-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be784b1d837c9b66b5fa406',
#        'name': 'Fusion Sushi',
#        'location': {'address': '1200 Pacific Coast Hwy',
#         'lat': 33.86415465590981,
#         'lng': -118.39275464650866,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86415465590981,
#           'lng': -118.39275464650866}],
#         'distance': 291,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1200 Pacific Coast Hwy',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '554142',
#         'url': 'https://www.grubhub.com/restaurant/fusion-sushi-1200-pacific-coast-hwy-hermosa-beach/554142?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=554142',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be784b1d837c9b66b5fa406-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a982de8f964a520d32a20e3',
#        'name': 'Paciugo Gelato',
#        'location': {'address': '1034 Hermosa Ave',
#         'crossStreet': 'at 10th St',
#         'lat': 33.86125051188469,
#         'lng': -118.39969611107662,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86125051188469,
#           'lng': -118.39969611107662}],
#         'distance': 486,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1034 Hermosa Ave (at 10th St)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '1733235',
#         'url': 'https://www.grubhub.com/restaurant/paciugo-gelato-and-caffe-1034-hermosa-ave-hermosa-beach/1733235?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1733235',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '82290928'}},
#       'referralId': 'e-0-4a982de8f964a520d32a20e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '598ba023bcbf7a39a47c4c77',
#        'name': 'Nekter Juice Bar',
#        'location': {'address': '703 Pier Avenue',
#         'lat': 33.86507,
#         'lng': -118.394654,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 33.864836,
#           'lng': -118.394861},
#          {'label': 'display', 'lat': 33.86507, 'lng': -118.394654}],
#         'distance': 145,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['703 Pier Avenue',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '610060',
#         'url': 'https://www.grubhub.com/restaurant/nekter-juice-bar-703-pier-ave-hermosa-beach/610060?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=610060',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '587297957'}},
#       'referralId': 'e-0-598ba023bcbf7a39a47c4c77-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4542c316f964a5205b3c1fe3',
#        'name': 'Paisanos Pizza & Pasta',
#        'location': {'address': '1132 Hermosa Ave',
#         'crossStreet': 'Pier Ave.',
#         'lat': 33.86184529418338,
#         'lng': -118.39977597542311,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86184529418338,
#           'lng': -118.39977597542311},
#          {'label': 'entrance', 'lat': 33.861921, 'lng': -118.399772}],
#         'distance': 448,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1132 Hermosa Ave (Pier Ave.)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2534025',
#         'url': 'https://www.grubhub.com/restaurant/paisanos-pizza--pasta-1132-hermosa-ave-hermosa-beach/2534025?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2534025',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4542c316f964a5205b3c1fe3-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b65f091f964a520cb092be3',
#        'name': 'Hermosa Beach Community Center',
#        'location': {'address': '710 Pier Ave',
#         'crossStreet': 'Pacific Coast Hwy',
#         'lat': 33.86702792118517,
#         'lng': -118.39493815193357,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86702792118517,
#           'lng': -118.39493815193357}],
#         'distance': 318,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['710 Pier Ave (Pacific Coast Hwy)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d126941735',
#          'name': 'Government Building',
#          'pluralName': 'Government Buildings',
#          'shortName': 'Government',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b65f091f964a520cb092be3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf847f95317a593f88bff7e',
#        'name': 'Star Antiques Market',
#        'location': {'address': '526 Pier Ave',
#         'lat': 33.86428051474452,
#         'lng': -118.39628751855659,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86428051474452,
#           'lng': -118.39628751855659},
#          {'label': 'entrance', 'lat': 33.864279, 'lng': -118.39631}],
#         'distance': 34,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['526 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d116951735',
#          'name': 'Antique Shop',
#          'pluralName': 'Antique Shops',
#          'shortName': 'Antiques',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/antique_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf847f95317a593f88bff7e-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b04880df964a520ec5422e3',
#        'name': 'Starbucks',
#        'location': {'address': '1303 Hermosa Ave',
#         'lat': 33.86313002981216,
#         'lng': -118.40033636566274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86313002981216,
#           'lng': -118.40033636566274},
#          {'label': 'entrance', 'lat': 33.863136, 'lng': -118.400412}],
#         'distance': 428,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1303 Hermosa Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b04880df964a520ec5422e3-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7a0e52f964a5200d212fe3',
#        'name': 'CVS pharmacy',
#        'location': {'address': '711 Pier Ave',
#         'lat': 33.865659536449925,
#         'lng': -118.39486910238931,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.865659536449925,
#           'lng': -118.39486910238931},
#          {'label': 'entrance', 'lat': 33.865752, 'lng': -118.395287}],
#         'distance': 181,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['711 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7a0e52f964a5200d212fe3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4afe2efcf964a520922e22e3',
#        'name': "Chef Melba's Bistro",
#        'location': {'address': '1501 Hermosa Ave',
#         'crossStreet': '15th St.',
#         'lat': 33.86450828533139,
#         'lng': -118.40072267663291,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86450828533139,
#           'lng': -118.40072267663291},
#          {'label': 'entrance', 'lat': 33.864536, 'lng': -118.400785}],
#         'distance': 445,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1501 Hermosa Ave (15th St.)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4afe2efcf964a520922e22e3-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c251f8bf7ced13aac05246d',
#        'name': 'Starbucks',
#        'location': {'address': '715 Pier Ave',
#         'lat': 33.865963,
#         'lng': -118.394487,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.865963,
#           'lng': -118.394487}],
#         'distance': 228,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['715 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c251f8bf7ced13aac05246d-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54bd6c18498eb85a573b2352',
#        'name': 'The Grindz at 1601',
#        'location': {'address': '1601 Pacific Coast Hwy',
#         'lat': 33.866915346540566,
#         'lng': -118.39382962512963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.866915346540566,
#           'lng': -118.39382962512963},
#          {'label': 'entrance', 'lat': 33.866964, 'lng': -118.393831}],
#         'distance': 350,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1601 Pacific Coast Hwy',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b79fe',
#          'name': 'Hawaiian Restaurant',
#          'pluralName': 'Hawaiian Restaurants',
#          'shortName': 'Hawaiian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54bd6c18498eb85a573b2352-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5865d4fa53f5bb1926d4b344',
#        'name': 'Laurel Tavern',
#        'location': {'address': '1220 Hermosa Ave',
#         'lat': 33.862620254552496,
#         'lng': -118.4000271244225,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.862620254552496,
#           'lng': -118.4000271244225}],
#         'distance': 423,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1220 Hermosa Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5865d4fa53f5bb1926d4b344-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af5f184f964a5202eff21e3',
#        'name': 'Java Man',
#        'location': {'address': '157 Pier Ave',
#         'crossStreet': 'at Manhattan Ave',
#         'lat': 33.86300135695532,
#         'lng': -118.39925445365479,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86300135695532,
#           'lng': -118.39925445365479},
#          {'label': 'entrance', 'lat': 33.862961, 'lng': -118.399319}],
#         'distance': 340,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['157 Pier Ave (at Manhattan Ave)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '37545244'}},
#       'referralId': 'e-0-4af5f184f964a5202eff21e3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53753b05498ea9b7218695fe',
#        'name': 'Paradise Bowls',
#        'location': {'address': '1246',
#         'crossStreet': '13th',
#         'lat': 33.86304766657721,
#         'lng': -118.4001558881429,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86304766657721,
#           'lng': -118.4001558881429},
#          {'label': 'entrance', 'lat': 33.863054, 'lng': -118.400061}],
#         'distance': 415,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1246 (13th)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'shortName': 'Juice Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53753b05498ea9b7218695fe-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ac6c832f964a5203fb620e3',
#        'name': "Zane's",
#        'location': {'address': '1150 Hermosa Ave',
#         'crossStreet': 'at Pier Ave',
#         'lat': 33.8621547488786,
#         'lng': -118.39988327245715,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.8621547488786,
#           'lng': -118.39988327245715}],
#         'distance': 436,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1150 Hermosa Ave (at Pier Ave)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '316683',
#         'url': 'https://www.grubhub.com/restaurant/zanes-restaurant-1150-hermosa-ave-hermosa-beach/316683?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=316683',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '406637519'}},
#       'referralId': 'e-0-4ac6c832f964a5203fb620e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b709b53f964a520e4242de3',
#        'name': 'Curious',
#        'location': {'address': '128 Pier Ave',
#         'crossStreet': 'btw Hermosa Ave & Manhattan Ave',
#         'lat': 33.862358648391414,
#         'lng': -118.39939662958189,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.862358648391414,
#           'lng': -118.39939662958189}],
#         'distance': 386,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['128 Pier Ave (btw Hermosa Ave & Manhattan Ave)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d104951735',
#          'name': 'Boutique',
#          'pluralName': 'Boutiques',
#          'shortName': 'Boutique',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b709b53f964a520e4242de3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1072a9f964a520aa7023e3',
#        'name': 'Spyder II',
#        'location': {'address': '65 Pier Ave',
#         'lat': 33.862176216453896,
#         'lng': -118.40056216826775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.862176216453896,
#           'lng': -118.40056216826775},
#          {'label': 'entrance', 'lat': 33.862269, 'lng': -118.400533}],
#         'distance': 489,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['65 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f1941735',
#          'name': 'Board Shop',
#          'pluralName': 'Board Shops',
#          'shortName': 'Board Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/surfspot_',
#           'suffix': '.png'},
#          'primary': True}],
# ...
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0e0115d64c0f47e083275d',
#        'name': "McDonald's",
#        'location': {'address': '1107 Pacific Coast Hwy',
#         'lat': 33.86323416297492,
#         'lng': -118.39290976524353,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86323416297492,
#           'lng': -118.39290976524353},
#          {'label': 'entrance', 'lat': 33.86326, 'lng': -118.392789}],
#         'distance': 300,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1107 Pacific Coast Hwy',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '2456997',
#         'url': 'https://www.grubhub.com/restaurant/mcdonalds-1107-pacific-coast-hwy-hermosa-beach/2456997?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2456997',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0e0115d64c0f47e083275d-57'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc35a60dce4eee1fa8f719d',
#        'name': 'Quality Inn & Suites',
#        'location': {'address': '901 Aviation Blvd',
#         'lat': 33.863445,
#         'lng': -118.390905,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.863445,
#           'lng': -118.390905},
#          {'label': 'entrance', 'lat': 33.863363, 'lng': -118.390816}],
#         'distance': 471,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['901 Aviation Blvd',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '49932341'}},
#       'referralId': 'e-0-4bc35a60dce4eee1fa8f719d-58'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4522c8faf964a520de3a1fe3',
#        'name': 'Hampton Inn & Suites',
#        'location': {'address': '1530 Pacific Coast Hwy',
#         'lat': 33.86624643290539,
#         'lng': -118.39296072721481,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86624643290539,
#           'lng': -118.39296072721481},
#          {'label': 'entrance', 'lat': 33.866037, 'lng': -118.392973}],
#         'distance': 349,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1530 Pacific Coast Hwy',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4522c8faf964a520de3a1fe3-59'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c2fc7c85f68b9002c612ee0',
#        'name': 'Sosta',
#        'location': {'address': '439 Pier Ave',
#         'lat': 33.86449432373047,
#         'lng': -118.39704132080078,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86449432373047,
#           'lng': -118.39704132080078}],
#         'distance': 107,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['439 Pier Ave',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c2fc7c85f68b9002c612ee0-60'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ad4f8acc97f2842e4cc8ab6',
#        'name': 'Black Flour Crepes',
#        'location': {'lat': 33.86584005801381,
#         'lng': -118.3933439514247,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86584005801381,
#           'lng': -118.3933439514247}],
#         'distance': 293,
#         'postalCode': '90094',
#         'cc': 'US',
#         'city': 'Los Angeles',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Los Angeles, CA 90094', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1cb941735',
#          'name': 'Food Truck',
#          'pluralName': 'Food Trucks',
#          'shortName': 'Food Truck',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ad4f8acc97f2842e4cc8ab6-61'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0b27dbed259521c1431356',
#        'name': 'Hermosa Valley Greenbelt',
#        'location': {'address': '301 S Valley Dr to 1 Valley Dr',
#         'crossStreet': 'btw Francisco St & Herondo St',
#         'lat': 33.867047339612604,
#         'lng': -118.39496297937909,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.867047339612604,
#           'lng': -118.39496297937909}],
#         'distance': 320,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['301 S Valley Dr to 1 Valley Dr (btw Francisco St & Herondo St)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0b27dbed259521c1431356-62'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0ac86d009a0f479c0eeabf',
#        'name': 'Pier Ave.',
#        'location': {'address': 'Pier Ave.',
#         'lat': 33.867052400054135,
#         'lng': -118.39495645268586,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.867052400054135,
#           'lng': -118.39495645268586}],
#         'distance': 320,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Pier Ave.',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f9931735',
#          'name': 'Road',
#          'pluralName': 'Roads',
#          'shortName': 'Road',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/highway_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0ac86d009a0f479c0eeabf-63'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f14f81ce4b019e994b36fe8',
#        'name': 'Plaza Hermosa',
#        'location': {'address': 'Pier Ave',
#         'crossStreet': 'PCH',
#         'lat': 33.86350690323794,
#         'lng': -118.39245958123226,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86350690323794,
#           'lng': -118.39245958123226}],
#         'distance': 330,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Pier Ave (PCH)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f14f81ce4b019e994b36fe8-64'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4efa4891d5fba468628f2353',
#        'name': 'Turmeric',
#        'location': {'address': '1601 Pacific Coast Hwy Ste 155',
#         'lat': 33.86653150729033,
#         'lng': -118.39352130889893,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86653150729033,
#           'lng': -118.39352130889893}],
#         'distance': 334,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1601 Pacific Coast Hwy Ste 155',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4efa4891d5fba468628f2353-65'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '509d4e58e4b047228901d5cf',
#        'name': 'Gymboree',
#        'location': {'address': '1601 Pacific Coast Hwy #190',
#         'lat': 33.86683071733309,
#         'lng': -118.39377261941715,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86683071733309,
#           'lng': -118.39377261941715}],
#         'distance': 345,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1601 Pacific Coast Hwy #190',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#          'name': 'Athletics & Sports',
#          'pluralName': 'Athletics & Sports',
#          'shortName': 'Athletics & Sports',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-509d4e58e4b047228901d5cf-66'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5221769211d2a08920c92e52',
#        'name': 'Windmill Park',
#        'location': {'address': '1100 Pacific Coast Hwy',
#         'crossStreet': 'Aviation',
#         'lat': 33.86345672607422,
#         'lng': -118.39221954345703,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86345672607422,
#           'lng': -118.39221954345703}],
#         'distance': 353,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['1100 Pacific Coast Hwy (Aviation)',
#          'Hermosa Beach, CA 90254',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5221769211d2a08920c92e52-67'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f4123f1e4b0def9945084e1',
#        'name': 'Stairs @ PCH',
#        'location': {'lat': 33.86750581218071,
#         'lng': -118.39401721076625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.86750581218071,
#           'lng': -118.39401721076625}],
#         'distance': 399,
#         'postalCode': '90254',
#         'cc': 'US',
#         'city': 'Hermosa Beach',
#         'state': 'CA',
#         'country': 'United States',
#         'formattedAddress': ['Hermosa Beach, CA 90254', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f7941735',
#          'name': 'Flea Market',
#          'pluralName': 'Flea Markets',
#          'shortName': 'Flea Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f4123f1e4b0def9945084e1-68'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d767cabd6688cfa76331e15',
#        'name': 'Hermosa Beach Green Belt',
#        'location': {'lat': 33.8600149484468,
#         'lng': -118.39424543365818,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 33.8600149484468,
#           'lng': -118.39424543365818}],
#         'distance': 499,
#         'cc': 'US',
#         'state': 'California',
#         'country': 'United States',
#         'formattedAddress': ['California', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d767cabd6688cfa76331e15-69'}]}]}}

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = HB_results['response']['groups'][0]['items']
    
HB_nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
HB_nearby_venues =HB_nearby_venues.loc[:, filtered_columns]

# filter the category for each row
HB_nearby_venues['venue.categories'] = HB_nearby_venues.apply(get_category_type, axis=1)

# clean columns
HB_nearby_venues.columns = [col.split(".")[-1] for col in HB_nearby_venues.columns]

HB_nearby_venues.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                         name                     categories        lat  \
# 0          Creme de la Crepe              French Restaurant  33.864180
# 1    Hermosa Beach Fish Shop             Seafood Restaurant  33.865028
# 2  Fritto Misto Italian Cafe             Italian Restaurant  33.863774
# 3            The Source Cafe  Vegetarian / Vegan Restaurant  33.864499
# 4                 The Strand                          Trail  33.867030
#
#           lng
# 0 -118.397104
# 1 -118.394182
# 2 -118.398149
# 3 -118.396651
# 4 -118.394904

# %%
HB_nearby_venues.shape
# Out:
# (70, 4)

# %%
#looking at the Hermosa Beach venues categories
HB_nearby_venues['categories']
# Out:
# 0                 French Restaurant
# 1                Seafood Restaurant
# 2                Italian Restaurant
# 3     Vegetarian / Vegan Restaurant
# 4                             Trail
# 5                       Yoga Studio
# 6                      Burger Joint
# 7                         Wine Shop
# 8                Mexican Restaurant
# 9             Australian Restaurant
# 10              American Restaurant
# 11              Peruvian Restaurant
# 12                   Massage Studio
# 13               Mexican Restaurant
# 14                      Men's Store
# 15                             Café
# 16          New American Restaurant
# 17                     Burger Joint
# 18                 Sushi Restaurant
# 19                   Ice Cream Shop
# 20                        Juice Bar
# 21                      Pizza Place
# 22              Government Building
# 23                     Antique Shop
# 24                      Coffee Shop
# 25                         Pharmacy
# 26               Italian Restaurant
# 27                      Coffee Shop
# 28              Hawaiian Restaurant
# 29              American Restaurant
# 30                      Coffee Shop
# 31                        Juice Bar
# 32                       Restaurant
# 33                         Boutique
# 34                       Board Shop
# 35                    Grocery Store
# 36                           Lounge
# 37                       Shoe Store
# 38                       Board Shop
# 39                              Spa
# 40                      Pizza Place
# 41                       Steakhouse
# 42                      Yoga Studio
# 43                             Bank
# 44                              Bar
# 45                       Sports Bar
# 46                       Poke Place
# 47                       Restaurant
# 48                    Grocery Store
# 49                 Sushi Restaurant
# 50                   Shipping Store
# 51                            Hotel
# 52                              Pub
# 53             Gym / Fitness Center
# 54               Chinese Restaurant
# 55                      Gas Station
# 56                   Farmers Market
# 57             Fast Food Restaurant
# 58                            Hotel
# 59                            Hotel
# 60               Italian Restaurant
# 61                       Food Truck
# 62                            Trail
# 63                             Road
# 64                    Shopping Mall
# 65                Indian Restaurant
# 66               Athletics & Sports
# 67                             Park
# 68                      Flea Market
# 69                             Park
# Name: categories, dtype: object

# %%
# creating a map of all the local venues in the Hermosa Beach area
HBV_map=folium.Map(location=[33.86428, -118.39591], zoom_start=16)
for i,row in HB_nearby_venues.iterrows():
    folium.Marker(location=[row['lat'],row['lng']], popup=row["name"]).add_to(HBV_map)
HBV_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_826d327b31394471a9afc7e44bf03c88%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_826d327b31394471a9afc7e44bf03c88%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_826d327b31394471a9afc7e44bf03c88%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_826d327b31394471a9afc7e44bf03c88%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B33.86428%2C%20-118.39591%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
#pulling the information about Hermosa Beach and El Segundo out of the dataframe
df.iloc[[126,175]]
# Out:
#               Name  Type       County Population (2010)[1][8][9] Land area[1]  \
#               Name  Type       County Population (2010)[1][8][9]        sq mi
# 126     El Segundo  City  Los Angeles                      16654         5.46
# 175  Hermosa Beach  City  Los Angeles                      19506         1.43
#
#             Incorporated[7]
#       km2   Incorporated[7]
# 126  14.1  January 18, 1917
# 175   3.7  January 14, 1907

# %% [markdown]
# ## Results<a id='results'></a>

# %% [markdown]
# By pulling the information of Foursquare of the venues in both Hermosa Beach and El Segundo we could see all the type of business within those specific coordinates. The results from the above work are as follows.
# * Both El Segundo and Hermosa Beach, California have a similar amount of businesses.
# * Each city are very diverse in terms of venue categories.
# * Neither city has a comic book store which is good because that means both locations met one of the requirements posed by the client.
# * The search of population size for each city yielded that Hermosa Beach had a higher population by nearly 3,000 people.

# %% [markdown]
# ## Discussion<a id='discussion'></a>

# %% [markdown]
# While the two cities are very similar in terms of population and business venue categories, there are some difference that make them exceeding different. According the the city information pulled form Wikipedia, El Segundo is roughly 4x times larger than Hermosa Beach. Under normal situations for beach cities a larger city contain more people and a larger amount of the business to serve those people. However, El Segundo has 2 anomalies that make it larger without providing some of the benefits. The first folium map reveal that a large portion of the city is taken up by the Chevron Refinery and the Los Angeles Airport. While these places undoubtedly bring something to El Segundo, there are many unknowns that may impact these businesses. For example, noise pollution along side an increase of regular pollution only to name a few. Hermosa Beach while smaller it has not only a higher population but also more businesses within the city center. Having a diverse amount of the businesses in a single area can be conducive to not only grow but continue success.

# %% [markdown]
# ## Conclusion <a id='conclusion'></a>

# %% [markdown]
# This project was formed to answer the clients question on what city would be best to open a comic book store. Through the use of the Foursquare information along with population and size data from Wikipedia, I would recommend that the client stat his business in Hermosa Beach California. I came to this conclusion because Hermosa Beach not only has a higher population but they also have a much larger business center within the city. This larger business center would normally be a problem because of the increase amount of business in the area. However, due to the fact that the business the client wants to start is a speciality store and there is no other store in the area like it, the increase in people traffic could potentially help their business thrive. The client's business venture could symbiotical work with the other type of the businesses in the area.
